# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:/Users/dell/Desktop/Loan_Default_Risk_Prediction/data/raw/loan_default.csv")

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.drop(columns=['Loan_ID'], inplace=True)

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15276\3657246551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df['Married'].fillna(df['Married'].mode()[0], inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15276\891759981.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Married'].fillna(df['Married'].mode()[0], inplace=True)

# %%
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15276\495691802.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)

# %%
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0], inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15276\3324225749.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Self_Employed'].fillna(df['Self_Employed'].mode()[0], inplace=True)

# %%
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15276\2294035902.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)

# %%
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15276\289206775.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)

# %%
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15276\1608471621.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.to_csv("C:/Users/dell/Desktop/Loan_Default_Risk_Prediction/data/processed/loan_cleaned.csv", index=False)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.boxplot(df['LoanAmount'])
plt.title('Boxplot of loan amount')
plt.ylabel('LoanAmount')
plt.show()

# %%
outliers = df[df['LoanAmount'] > 270]

print("Number of outliers:", outliers.shape[0])
outliers.head()
# Out:
# Number of outliers: 39
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 9     Male     Yes          1  Graduate            No            12841
# 21    Male     Yes          1  Graduate            No             5955
# 34    Male      No         3+  Graduate            No            12500
# 54  Female     Yes          1  Graduate           Yes            11500
# 67    Male     Yes          1  Graduate            No            10750
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 9             10968.0       349.0             360.0             1.0
# 21             5625.0       315.0             360.0             1.0
# 34             3000.0       320.0             360.0             1.0
# 54                0.0       286.0             360.0             0.0
# 67                0.0       312.0             360.0             1.0
#
#    Property_Area Loan_Status
# 9      Semiurban           N
# 21         Urban           Y
# ...

# %%
numerical_cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

for col in numerical_cols:
    plt.figure(figsize=(6,4))
    plt.boxplot(df[col].dropna())
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
def detect_outliers(df, column):
    
    # Calculate Quartiles
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)

    # Calculate IQR
    IQR = Q3 - Q1

    # Calculate Bounds
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)

    # Detect Outliers
    outliers = df[
        (df[column] < lower_bound) |
        (df[column] > upper_bound)
    ]

    # Print Summary
    print("=" * 50)
    print(f"Column : {column}")
    print(f"Q1 : {Q1}")
    print(f"Q3 : {Q3}")
    print(f"IQR : {IQR}")
    print(f"Lower Bound : {lower_bound}")
    print(f"Upper Bound : {upper_bound}")
    print(f"Number of Outliers : {outliers.shape[0]}")
    print("\nSample Outliers:")
    print(outliers.head())

    return outliers

# %%
detect_outliers(df, 'ApplicantIncome')
# Out:
# ...
# Column : ApplicantIncome
# Q1 : 2877.5
# Q3 : 5795.0
# IQR : 2917.5
# Lower Bound : -1498.75
# Upper Bound : 10171.25
# Number of Outliers : 50
#
# Sample Outliers:
#      Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 9      Male     Yes          1  Graduate            No            12841
# 34     Male      No         3+  Graduate            No            12500
# 54   Female     Yes          1  Graduate           Yes            11500
# 67     Male     Yes          1  Graduate            No            10750
# 102    Male     Yes          0  Graduate            No            13650
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 9              10968.0       349.0             360.0             1.0
# 34              3000.0       320.0             360.0             1.0
# 54                 0.0       286.0             360.0             0.0
# 67                 0.0       312.0             360.0             1.0
# ...

# %%
detect_outliers(df, 'CoapplicantIncome')
# Out:
# ...
# Column : CoapplicantIncome
# Q1 : 0.0
# Q3 : 2297.25
# IQR : 2297.25
# Lower Bound : -3445.875
# Upper Bound : 5743.125
# Number of Outliers : 18
#
# Sample Outliers:
#      Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 9      Male     Yes          1  Graduate            No            12841
# 12     Male     Yes          2  Graduate            No             3073
# 38     Male      No          0  Graduate            No             4166
# 122  Female      No          0  Graduate            No             2137
# 135    Male     Yes         3+  Graduate            No             4000
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 9              10968.0       349.0             360.0             1.0
# 12              8106.0       200.0             360.0             1.0
# 38              7210.0       184.0             360.0             1.0
# 122             8980.0       137.0             360.0             0.0
# ...

# %%
detect_outliers(df, 'LoanAmount')
# Out:
# ...
# Column : LoanAmount
# Q1 : 100.25
# Q3 : 164.75
# IQR : 64.5
# Lower Bound : 3.5
# Upper Bound : 261.5
# Number of Outliers : 41
#
# Sample Outliers:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 5     Male     Yes          2  Graduate           Yes             5417
# 9     Male     Yes          1  Graduate            No            12841
# 21    Male     Yes          1  Graduate            No             5955
# 34    Male      No         3+  Graduate            No            12500
# 54  Female     Yes          1  Graduate           Yes            11500
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 5              4196.0       267.0             360.0             1.0
# 9             10968.0       349.0             360.0             1.0
# 21             5625.0       315.0             360.0             1.0
# 34             3000.0       320.0             360.0             1.0
# ...
